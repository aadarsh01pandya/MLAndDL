# %%
import numpy as np
import cv2 
import skimage
import matplotlib.pyplot as plt

# %%
#!python -m pip install matplotlib
#!python -m pip install opencv-python
#!python -m pip install scikit-image
#!python -m pip install pillow

# %%
#compuer vision --> dip(digital image)

# %%
image1=plt.imread('cat.jpg')
plt.imshow(image1)
plt.axis('off')
# Out:
# (-0.5, 611.5, 583.5, -0.5)

# %%
image2=cv2.imread('dog.jpg')
cv2.imshow('image2',image2)
cv2.waitKey(0)

# jab hum lod waitkey ka walie 0 karta ha tub nich wala statement excuted kar na ha

#cv2.destroyAllWindows()
# Out:
# -1

# %%
img3=skimage.io.imread('cat.jpg')
skimage.io.imshow(img3)

# %%
img3
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
type(img3) ,type(image2) ,type(image1)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
img3.shape
# Out:
# (584, 612, 3)

# %%
img3.size
# Out:
# 1072224

# %%
r1=np.random.randint(0,255,(500,500))
r1.shape
plt.imshow(r1)

# %%
r2=np.random.randint(0,255,(500,500))
r2.shape
plt.imshow(r2,cmap='gray')

# %%
r3=np.random.randint(0,255,(50,50))
r3.shape
plt.imshow(r3,cmap='gray')

# %%
img=np.ones((50,50,3) , dtype='uint8')*255

img[:25,:25,1:]= 0  #img[:25,:25,1:]*0
img[:25,25:,::2]= 0  #img[:25,:25,::2]*0
img[25:,:25,:2]= 0 #img[25:,25:,2:]*0
img[25:,25:,2:]=0
plt.imshow(img)

# %%
plt.imsave('square.png',img)

# %%
#cv2 sa save karana sa colour diffrent hoga becouse BGR formate

# %%
skimage.io.imshow(img3[:,:,::-1])

# %%
cv2.imwrite("square box.jpg",img[:,:,::-1])
# Out:
# True
